# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashijain07/rashi_jain/blob/main/Exam_Mark_Prediction_using_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Accessing dataset from directory

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-41eec5c6-2b8c-4ff7-9512-4cf12686579e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41eec5c6-2b8c-4ff7-9512-4cf12686579e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Load dataset

# %%
dataset= pd.read_csv("std_marks_data.csv")
dataset
# Out:
#      hours  age  internet  marks
# 0     6.84   15         0  78.64
# 1     6.56   20         1  88.80
# 2      NaN   21         1  88.90
# 3     8.67   22         1  98.99
# 4     7.55   17         1  92.34
# ..     ...  ...       ...    ...
# 295   2.99   25         0  43.45
# 296   6.55   15         1  77.74
# 297   0.00   20         1  75.76
# 298   9.90   22         0  99.99
# 299   3.40   21         0  99.99
#
# [300 rows x 4 columns]

# %% [markdown]
# Summarize dataset

# %%
print(dataset.shape)
print(dataset.head())
# Out:
# (300, 4)
#    hours  age  internet  marks
# 0   6.84   15         0  78.64
# 1   6.56   20         1  88.80
# 2    NaN   21         1  88.90
# 3   8.67   22         1  98.99
# 4   7.55   17         1  92.34

# %% [markdown]
# Finding and Removing NA values from the dataset

# %%
dataset.columns[dataset.isna().any()]
# Out:
# Index(['hours'], dtype='object')

# %%
dataset.hours= dataset.hours.fillna(dataset.hours.mean())

# %%
dataset
# Out:
#         hours  age  internet  marks
# 0    6.840000   15         0  78.64
# 1    6.560000   20         1  88.80
# 2    5.494514   21         1  88.90
# 3    8.670000   22         1  98.99
# 4    7.550000   17         1  92.34
# ..        ...  ...       ...    ...
# 295  2.990000   25         0  43.45
# 296  6.550000   15         1  77.74
# 297  0.000000   20         1  75.76
# 298  9.900000   22         0  99.99
# 299  3.400000   21         0  99.99
#
# [300 rows x 4 columns]

# %% [markdown]
# Segregate dataset into X & Y

# %%
X=dataset.iloc[:,:-1]
X
# Out:
#         hours  age  internet
# 0    6.840000   15         0
# 1    6.560000   20         1
# 2    5.494514   21         1
# 3    8.670000   22         1
# 4    7.550000   17         1
# ..        ...  ...       ...
# 295  2.990000   25         0
# 296  6.550000   15         1
# 297  0.000000   20         1
# 298  9.900000   22         0
# 299  3.400000   21         0
#
# [300 rows x 3 columns]

# %%
Y= dataset.iloc[:,1]
Y
# Out:
# 0      15
# 1      20
# 2      21
# 3      22
# 4      17
#        ..
# 295    25
# 296    15
# 297    20
# 298    22
# 299    21
# Name: age, Length: 300, dtype: int64

# %% [markdown]
# Training

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Predicted Price for Land sq.Feet of custom values

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
a=[[10.2,18,1]]
PredictedmodelResult= model.predict(a)
print(PredictedmodelResult)
# Out:
# [18.]
